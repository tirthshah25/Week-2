# %% [markdown]
# ## Solar Power Prediction using Linear Regression Model

# %%
# installing and importing necessary libraries
! pip install pandas numpy seaborn 
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.5 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.5 MB 3.5 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.5 MB 3.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.5 MB 3.9 MB/s eta 0:00:03
#    ------------ --------------------------- 3.7/11.5 MB 3.5 MB/s eta 0:00:03
#    -------------- ------------------------- 4.2/11.5 MB 3.5 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.5 MB 3.6 MB/s eta 0:00:02
#    --------------------- ------------------ 6.3/11.5 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.5 MB 3.7 MB/s eta 0:00:02
#    --------------------------- ------------ 7.9/11.5 MB 3.7 MB/s eta 0:00:01
# ...

# %%
# load the dataset 
df = pd.read_csv('Dataset/Dataset.csv')
# display the first few rows of the dataset 
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.tail()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 4208                       8.69                               66
# 4209                       7.57                               90
# 4210                       7.27                               90
# 4211                       8.25                               81
# 4212                       8.00                               80
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 4208                       1025.1                      0.0
# 4209                       1026.1                      0.0
# 4210                       1026.3                      0.1
# 4211                       1025.5                      0.0
# 4212                       1025.3                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 4208                  0.0                  100.0
# 4209                  0.0                  100.0
# 4210                  0.0                  100.0
# ...

# %%
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
# to check the total no. of rows and coloumns in the dataset
df.shape
# Out:
# (4213, 21)

# %%
# display summary 
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
# check the information of the dataset 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
# check for the missing values 
df.isnull()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 4208                      False                            False
# 4209                      False                            False
# 4210                      False                            False
# 4211                      False                            False
# 4212                      False                            False
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 0                           False                    False
# 1                           False                    False
# ...

# %%
# check for the duplicate values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['temperature_2_m_above_gnd', 'relative_humidity_2_m_above_gnd',
#        'mean_sea_level_pressure_MSL', 'total_precipitation_sfc',
#        'snowfall_amount_sfc', 'total_cloud_cover_sfc',
#        'high_cloud_cover_high_cld_lay', 'medium_cloud_cover_mid_cld_lay',
#        'low_cloud_cover_low_cld_lay', 'shortwave_radiation_backwards_sfc',
#        'wind_speed_10_m_above_gnd', 'wind_direction_10_m_above_gnd',
#        'wind_speed_80_m_above_gnd', 'wind_direction_80_m_above_gnd',
#        'wind_speed_900_mb', 'wind_direction_900_mb',
#        'wind_gust_10_m_above_gnd', 'angle_of_incidence', 'zenith', 'azimuth',
#        'generated_power_kw'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
# plot the distribution of power
plt.figure(figsize=(10,6))
sns.histplot(df['generated_power_kw'], bins=30, kde=True)
plt.title('Distribution of Generated Power(kW)')
plt.xlabel('Generated Power(kW)')
plt.ylabel('Frequency')
plt.show()

# %%
# ============================
# 🔹 Handling Outliers using IQR
# ============================
import numpy as np
# Ensure dataset is loaded before using it
import pandas as pd

df = pd.read_csv('Dataset/Dataset.csv')  # Make sure the path is correct
print("Dataset loaded successfully!")


Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
print("Outliers removed successfully!")

# ============================
# 🔹 Time Series Analysis (if applicable)
# ============================
import matplotlib.pyplot as plt

if 'timestamp' in df.columns:
    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df.set_index('timestamp', inplace=True)

    plt.figure(figsize=(12, 6))
    df['TargetColumn'].plot()
    plt.title("Time Series Trend of Target Variable")
    plt.xlabel("Time")
    plt.ylabel("Target Variable")
    plt.show()

# ============================
# 🔹 Feature Importance using RandomForest
# ============================
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
feature_importances = pd.Series(rf.feature_importances_, index=X.columns)
feature_importances.nlargest(10).plot(kind='barh')
plt.title("Top 10 Feature Importances")
plt.show()

# ============================
# 🔹 Trying Additional Models (Gradient Boosting & XGBoost)
# ============================
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from sklearn.metrics import mean_squared_error

gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)
print(f"Gradient Boosting RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_gb)):.4f}")

xgb_model = xgb.XGBRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train, y_train)
y_pred_xgb = xgb_model.predict(X_test)
print(f"XGBoost RMSE: {np.sqrt(mean_squared_error(y_test, y_pred_xgb)):.4f}")

# ============================
# 🔹 Deploying Model as API using Flask
# ============================
from flask import Flask, request, jsonify
import joblib

app = Flask(__name__)
model = joblib.load('solar_power_model.pkl')

@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()
    features = np.array(data['features']).reshape(1, -1)
    prediction = model.predict(features)
    return jsonify({'prediction': prediction.tolist()})

if __name__ == '__main__':
    app.run(debug=True)

# ============================
# 🔹 Streamlit Dashboard for Model Predictions
# ============================
import streamlit as st

st.title("Solar Power Prediction")

input_features = []
for col in X.columns:
    input_features.append(st.number_input(f"Enter {col}", value=0.0))

if st.button("Predict"):
    features_array = np.array(input_features).reshape(1, -1)
    prediction = model.predict(features_array)
    st.write(f"Predicted Power Output: {prediction[0]:.2f}")
# Out:
# Dataset loaded successfully!
# Outliers removed successfully!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 38
#      33     plt.show()
#      35 # ============================
#      36 # 🔹 Feature Importance using RandomForest
#      37 # ============================
# ---> 38 from sklearn.ensemble import RandomForestRegressor
#      40 rf = RandomForestRegressor(n_estimators=100, random_state=42)
#      41 rf.fit(X_train, y_train)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip install scikit-learn
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.1 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.1 MB 4.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.1 MB 4.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.1 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.1 MB 4.2 MB/s eta 0:00:02
#    ------------------ --------------------- 5.2/11.1 MB 4.2 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.1 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.1 MB 4.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.1 MB 4.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.1 MB 4.0 MB/s eta 0:00:01
# ...
